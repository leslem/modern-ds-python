# %% [markdown]
# # Modern Data Science in Python: Polars

# %%
import polars as pl

# %%
pl.read_parquet("data/projects.parquet").filter(pl.col("tags").list.contains("python"))

# %%
pl.read_parquet("data/metrics.parquet").filter(project="plotnine").head(100)
